# %%
# 화면에 한 번 출력하고 입력대기 상태가 된다.
# 입력받은 것은 모두 문자열이다.

# %%
input("이름은요? ")
# Out:
# 이름은요?  하나
# '하나'

# %%
age1 = input("나이는요? ")
# Out:
# 나이는요?  13

# %%
age2 = input("나이는요? ")
# Out:
# 나이는요?  15

# %%
int(age1) + int(age2)
# Out:
# 28

# %%
age1 = int(input("나이는요? "))
age2 = int(input("나이는요? "))
# Out:
# 나이는요?  13
# 나이는요?  15

# %%
age1 + age2
# Out:
# 28

# %%
inch= int(input("몇 인치: "))
# Out:
# 몇 인치:  13

# %%
type(inch)
# Out:
# int

# %%
print(f"{inch*2.54} cm 입니다.")
# Out:
# 33.02 cm 입니다.

# %%
inch= float(input("몇 인치: "))
# Out:
# 몇 인치:  15.3

# %%
print(f"{inch*2.54} cm 입니다.")
# Out:
# 38.862 cm 입니다.

# %%
inch= float(input("몇 인치: "))
# Out:
# 몇 인치:  13

# %%
print(f"{inch*2.54} cm 입니다.")
# Out:
# 33.02 cm 입니다.

# %% [markdown]
# float로 입력해서 알아서 소수로 인식됨.

# %%
a = "Good morning"
a
# Out:
# 'Good morning'

# %%
# 문자열은 객체이다. (object)

# %%
a.upper()

# 대문자로 바꿔주는 함수.
# Out:
# 'GOOD MORNING'

# %% [raw]
# # 객체. 메서드

# %%
a.title()
# Out:
# 'Good Morning'

# %%
a = "GOOD MORning"
a
# Out:
# 'GOOD MORning'

# %%
a.lower
# Out:
# <function str.lower()>

# %%
a.capitalize()
# Out:
# 'Good morning'

# %%
a.upper().lower().capitalize()
# Out:
# 'Good morning'

# %%
a = "Hello123"
a
# Out:
# 'Hello123'

# %%
a.strip()

# 공백을 없애는 함수
# Out:
# 'Hello'

# %%
a.rstrip()

# 오른쪽 공백만 없애는
# Out:
# '  Hello'

# %%
a.lstrip()

# 왼쪽 공백만 없애는
# Out:
# 'Hello  '

# %%
# is000 : 이다 아니다 (ex. 숫자인지 아닌지 / 글자인지 아닌지)
a.isalpha()
# a 가 알파벳인가?
# Out:
# False

# %%
a.isalnum()
# 숫자와 알파벳이 같이 있는지?
# Out:
# True

# %%
a.find("e")
# Out:
# 1

# %%
# 이 글자가 몇번째 인지 알고 싶을 때

a.find("o")

# 인덱스 넘버로 알려줌
# Out:
# 4

# %%
a.find("l")

# 여러개 있을 때는 맨 앞에 있는 걸 보여줌.
# Out:
# 2

# %%
age = 30
"나이는 {}세 입니다.".format(age)
# Out:
# '나이는 30세 입니다.'

# %%
a = "10 20 30 40"
a.split()

#쪼개주는 함수 > 아무것도 안쓸 경우 디폴트가 스페이스 단위로 쪼개줌.
# Out:
# ['10', '20', '30', '40']

# %%
a = "10,20,30,40,100"
li = a.split(",")
li
# Out:
# ['10', '20', '30', '40', '100']

# %%
for i in li:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 100

# %%
total = 0
for i in li:
    total = total + int(i)
    print(total)
# Out:
# 10
# 30
# 60
# 100
# 200

# %%
total = 0
for i in li:
    total += int(i)
print(total)
# Out:
# 200

# %%
total = 0
for i in li:
    total += int(i)
print(total/5)
# Out:
# 40.0

# %%
total = 0
for i in li:
    total += int(i)
print(total/len(li))

# 평균 내기
# Out:
# 40.0

# %%
",  ".join(li)

# split의 반대말 join
# Out:
# '10,  20,  30,  40,  100'

# %%
"Hello123".isalpha()
"Hello123".isnumeric()
"Hello123".isalnum()
# Out:
# True

# %%
a = '1234'
if a.isnumeric():
    print(int(a))
# Out:
# 1234

# %%
"Hello123".startswith("H")
"Hello123".endswith("3")
# Out:
# True

# %%
1 < 2
# Out:
# True

# %%
"a" < "b"

# 아스키코드 참조
# Out:
# True

# %%
# 유니코드는 - 전세계 문자

# %%
if 조건 :
    실행될 문장
    실행될 문장
    실행될 문장
